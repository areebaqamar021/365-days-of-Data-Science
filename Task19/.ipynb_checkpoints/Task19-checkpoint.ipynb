# %% [markdown]
# # Statistical plotting with Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

tips.replace([np.inf, -np.inf], np.nan, inplace=True)
flights.replace([np.inf, -np.inf], np.nan, inplace=True)
iris.replace([np.inf, -np.inf], np.nan, inplace=True)

# %% [markdown]
# ## Linear Regression Plot

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='total_bill', y='tip', data=tips)
plt.title('Linear Regression Plot: Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# ## Multiple Linear Regression Plot

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', data=tips, aspect=2, height=6)
plt.title('Multiple Linear Regression Plot: Total Bill vs Tip by Smoker')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %% [markdown]
# ## Residual Plot

# %%
plt.figure(figsize=(10, 6))
sns.residplot(x='total_bill', y='tip', data=tips)
plt.title('Residual Plot: Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# ## Histogram

# %%
plt.figure(figsize=(10, 6))
sns.histplot(tips['total_bill'], bins=30, kde=True)
plt.title('Histogram of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\areeb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ##

# %%
plt.figure(figsize=(8, 6))
sns.kdeplot(tips['total_bill'], fill=True)
plt.title('Kernel Density Estimate Plot of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\areeb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Distribution Plot

# %%
plt.figure(figsize=(8, 6))
sns.distplot(tips['total_bill'], bins=10, hist=True, kde=True, rug=False)
plt.title('Distribution Plot of Total Bill')
plt.xlabel('Total Bill')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\areeb\AppData\Local\Temp\ipykernel_11780\2958272274.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['total_bill'], bins=10, hist=True, kde=True, rug=False)
# C:\Users\areeb\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
